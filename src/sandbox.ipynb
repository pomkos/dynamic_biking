# %%
import pandas as pd
import datetime as dt

# %%
import numpy as np

# %%
data
# Out:
#          Time           Session Timer  Interval Timer Speed(RPM)     Power(w)  \
# 0    18:45:41                 0:00:03         0:00:03       10.7          3.7
# 1    18:45:42                 0:00:04         0:00:04       27.3         11.1
# 2    18:45:43                 0:00:05         0:00:05       35.6         16.7
# 3    18:45:44                 0:00:06         0:00:06       37.0         17.9
# 4    18:45:45                 0:00:07         0:00:07       41.0         19.9
# ..        ...                     ...             ...        ...          ...
# 117  18:47:38                 0:02:00         0:01:48        0.0         -0.0
# 118  18:47:39                 0:02:01         0:01:49        0.0         -0.0
# 119  18:47:40                 0:02:02         0:01:50        0.1         -0.0
# 120  18:47:41                 0:02:03         0:01:51        0.0         -0.0
# 121  18:47:42                 0:02:04         0:01:52        0.1         -0.0
#
# ...

# %%
from helpers.helper_functions import bike_v2_data_loader, bike_v3_data_loader

# %%
bike_v2_data_loader('../input/02_03_2023Time10_23_29_Dynamic_SS1_002.txt', 1, None)
# Out:
#      participant session                date     timer  seconds_elapsed  \
# 0            SS1     002 2023-02-03 10:23:35  00:00:02              2.0
# 1            SS1     002 2023-02-03 10:23:36  00:00:03              3.0
# 2            SS1     002 2023-02-03 10:23:37  00:00:04              4.0
# 3            SS1     002 2023-02-03 10:23:38  00:00:05              5.0
# 4            SS1     002 2023-02-03 10:23:39  00:00:06              6.0
# ...          ...     ...                 ...       ...              ...
# 1696         SS1     002 2023-02-03 10:53:37  00:30:05           1805.0
# 1697         SS1     002 2023-02-03 10:53:38  00:30:06           1806.0
# 1698         SS1     002 2023-02-03 10:53:39  00:30:07           1807.0
# 1699         SS1     002 2023-02-03 10:53:40  00:30:09           1809.0
# 1700         SS1     002 2023-02-03 10:53:41  00:30:10           1810.0
#
#       speed_rpm  power_watt  heart_rate  id_sess
# 0          20.0         4.3         0.0  SS1_002
# ...

# %%
df = bike_v3_data_loader('../input/enth001_session001_01_12_2023Time20_00_36_Dynamic.txt', 1, None)

# %%
df[['participant', 'session', 'date', 'session_timer', 'seconds_elapsed_session', 'seconds_elapsed_interval', 'interval_timer', 'speed_rpm', 'power_watt', 'heart_rate', 'id_sess']]
# Out:
#      participant     session                date    session_timer  \
# 0        enth001  session001 2023-01-12 20:00:39  0:00:03
# 1        enth001  session001 2023-01-12 20:00:40  0:00:04
# 2        enth001  session001 2023-01-12 20:00:41  0:00:05
# 3        enth001  session001 2023-01-12 20:00:42  0:00:06
# 4        enth001  session001 2023-01-12 20:00:43  0:00:07
# ...          ...         ...                 ...              ...
# 1812     enth001  session001 2023-01-12 20:30:51  0:30:15
# 1813     enth001  session001 2023-01-12 20:30:52  0:30:16
# 1814     enth001  session001 2023-01-12 20:30:53  0:30:17
# 1815     enth001  session001 2023-01-12 20:30:54  0:30:18
# 1816     enth001  session001 2023-01-12 20:30:55  0:30:19
#
#       seconds_elapsed_session  seconds_elapsed_interval   interval_timer  \
# 0                         3.0                       0.0  0:00:00
# 1                         4.0                       1.0  0:00:01
# ...
